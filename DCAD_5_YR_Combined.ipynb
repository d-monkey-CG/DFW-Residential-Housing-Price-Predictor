# %%
import pandas as pd

df_1 = pd.read_csv('DCAD_Joined_2021.csv', low_memory=False)
df_2 = pd.read_csv('DCAD_Joined_2022.csv', low_memory=False)
df_3 = pd.read_csv('DCAD_Joined_2023.csv', low_memory=False)
df_4 = pd.read_csv('DCAD_Joined_2024.csv', low_memory=False)
df_5 = pd.read_csv('DCAD_Joined_2025.csv', low_memory=False)


DCAD_5YR_df = pd.concat([df_1, df_2, df_3, df_4, df_5], axis=0, ignore_index=True)

# %%
DCAD_5YR_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4264162 entries, 0 to 4264161
# Data columns (total 11 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   ACCOUNT_NUM       object
#  1   LAND_VAL          float64
#  2   TOT_VAL           float64
#  3   APPRAISAL_YR      int64
#  4   STREET_NUM        float64
#  5   STREET_HALF_NUM   object
#  6   FULL_STREET_NAME  object
#  7   PROPERTY_ZIPCODE  object
#  8   YR_BUILT          float64
#  9   TOT_MAIN_SF       float64
#  10  POOL_IND          object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 357.9+ MB

# %%
DCAD_5YR_df.to_parquet

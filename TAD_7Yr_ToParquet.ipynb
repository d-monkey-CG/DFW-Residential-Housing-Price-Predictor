# %%
import pandas as pd

df_1 = pd.read_excel('2019ResidentialCompAttributeData.xlsx')
df_2 = pd.read_excel('2020ResidentialCompAttributeData.xlsx')
df_3 = pd.read_excel('2021ResidentialCompAttributeData.xlsx')
df_4 = pd.read_excel('2022ResidentialCompAttributeData.xlsx')
df_5 = pd.read_excel('2023ResidentialCompAttributeData.xlsx')
df_6 = pd.read_excel('2024ResidentialCompAttributeData.xlsx')
df_7 = pd.read_excel('2025ResidentialCompAttributeData.xlsx')

TAD_7yr_df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7], axis=0, ignore_index=True)

# %%
TAD_7yr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4460919 entries, 0 to 4460918
# Data columns (total 18 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   TaxYear               int64
#  1   PIN                   int64
#  2   Neighborhood          object
#  3   SitusAddress          object
#  4   ImprovementType       object
#  5   ImprovementStyle      object
#  6   Quality               object
#  7   Condition             object
#  8   YearBuilt             float64
#  9   ActualArea            float64
#  10  LandValue             int64
#  11  GarageValue           int64
#  12  PoolValue             int64
#  13  OutbuildingValue      int64
#  14  OtherFeatureValue     int64
#  15  EffectiveYear         float64
#  16  IndicatedSalesValue   float64
#  17  IndicatedEquityValue  float64
# dtypes: float64(5), int64(7), object(6)
# memory usage: 612.6+ MB

# %%
TAD_7yr_df.to_parquet('TAD_7yr_Combined.parquet')
